# %%
import pandas as pd

# %%
trxn = pd.read_csv('Retail_Data_Transactions.csv')

# %%
trxn
# Out:
#        customer_id trans_date  tran_amount
# 0           CS5295  11-Feb-13           35
# 1           CS4768  15-Mar-15           39
# 2           CS2122  26-Feb-13           52
# 3           CS1217  16-Nov-11           99
# 4           CS1850  20-Nov-13           78
# ...            ...        ...          ...
# 124995      CS8433  26-Jun-11           64
# 124996      CS7232  19-Aug-14           38
# 124997      CS8731  28-Nov-14           42
# 124998      CS8133  14-Dec-13           13
# 124999      CS7996  13-Dec-14           36
#
# [125000 rows x 3 columns]

# %%
response = pd.read_csv ('Retail_Data_Response.csv')

# %%
response
# Out:
#      customer_id  response
# 0         CS1112         0
# 1         CS1113         0
# 2         CS1114         1
# 3         CS1115         1
# 4         CS1116         1
# ...          ...       ...
# 6879      CS8996         0
# 6880      CS8997         0
# 6881      CS8998         0
# 6882      CS8999         0
# 6883      CS9000         0
#
# [6884 rows x 2 columns]

# %%
df = trxn.merge(response, on = 'customer_id', how = 'left')

# %%
df
# Out:
#        customer_id trans_date  tran_amount  response
# 0           CS5295  11-Feb-13           35       1.0
# 1           CS4768  15-Mar-15           39       1.0
# 2           CS2122  26-Feb-13           52       0.0
# 3           CS1217  16-Nov-11           99       0.0
# 4           CS1850  20-Nov-13           78       0.0
# ...            ...        ...          ...       ...
# 124995      CS8433  26-Jun-11           64       0.0
# 124996      CS7232  19-Aug-14           38       0.0
# 124997      CS8731  28-Nov-14           42       0.0
# 124998      CS8133  14-Dec-13           13       0.0
# 124999      CS7996  13-Dec-14           36       0.0
#
# [125000 rows x 4 columns]

# %%
df.shape
# Out:
# (125000, 4)

# %%
df.info
# Out:
# <bound method DataFrame.info of        customer_id trans_date  tran_amount  response
# 0           CS5295  11-Feb-13           35       1.0
# 1           CS4768  15-Mar-15           39       1.0
# 2           CS2122  26-Feb-13           52       0.0
# 3           CS1217  16-Nov-11           99       0.0
# 4           CS1850  20-Nov-13           78       0.0
# ...            ...        ...          ...       ...
# 124995      CS8433  26-Jun-11           64       0.0
# 124996      CS7232  19-Aug-14           38       0.0
# 124997      CS8731  28-Nov-14           42       0.0
# 124998      CS8133  14-Dec-13           13       0.0
# 124999      CS7996  13-Dec-14           36       0.0
#
# [125000 rows x 4 columns]>

# %%
df.describe()
# Out:
#          tran_amount       response
# count  125000.000000  124969.000000
# mean       64.991912       0.110763
# std        22.860006       0.313840
# min        10.000000       0.000000
# 25%        47.000000       0.000000
# 50%        65.000000       0.000000
# 75%        83.000000       0.000000
# max       105.000000       1.000000

# %%
df.isnull().sum()
# Out:
# customer_id     0
# trans_date      0
# tran_amount     0
# response       31
# dtype: int64

# %%
df.dropna()
# Out:
#        customer_id trans_date  tran_amount  response
# 0           CS5295  11-Feb-13           35       1.0
# 1           CS4768  15-Mar-15           39       1.0
# 2           CS2122  26-Feb-13           52       0.0
# 3           CS1217  16-Nov-11           99       0.0
# 4           CS1850  20-Nov-13           78       0.0
# ...            ...        ...          ...       ...
# 124995      CS8433  26-Jun-11           64       0.0
# 124996      CS7232  19-Aug-14           38       0.0
# 124997      CS8731  28-Nov-14           42       0.0
# 124998      CS8133  14-Dec-13           13       0.0
# 124999      CS7996  13-Dec-14           36       0.0
#
# [124969 rows x 4 columns]

# %%
df ['trans_date'] = pd.to_datetime(df['trans_date'])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15456\3495554693.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df ['trans_date'] = pd.to_datetime(df['trans_date'])

# %%
df
# Out:
#        customer_id trans_date  tran_amount  response
# 0           CS5295 2013-02-11           35       1.0
# 1           CS4768 2015-03-15           39       1.0
# 2           CS2122 2013-02-26           52       0.0
# 3           CS1217 2011-11-16           99       0.0
# 4           CS1850 2013-11-20           78       0.0
# ...            ...        ...          ...       ...
# 124995      CS8433 2011-06-26           64       0.0
# 124996      CS7232 2014-08-19           38       0.0
# 124997      CS8731 2014-11-28           42       0.0
# 124998      CS8133 2013-12-14           13       0.0
# 124999      CS7996 2014-12-13           36       0.0
#
# [125000 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# customer_id     0
# trans_date      0
# tran_amount     0
# response       31
# dtype: int64

# %%
df = df.dropna()

# %%
df
# Out:
#        customer_id trans_date  tran_amount  response
# 0           CS5295 2013-02-11           35       1.0
# 1           CS4768 2015-03-15           39       1.0
# 2           CS2122 2013-02-26           52       0.0
# 3           CS1217 2011-11-16           99       0.0
# 4           CS1850 2013-11-20           78       0.0
# ...            ...        ...          ...       ...
# 124995      CS8433 2011-06-26           64       0.0
# 124996      CS7232 2014-08-19           38       0.0
# 124997      CS8731 2014-11-28           42       0.0
# 124998      CS8133 2013-12-14           13       0.0
# 124999      CS7996 2014-12-13           36       0.0
#
# [124969 rows x 4 columns]

# %%
df['response'] = df['response'].astype('int')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15456\3157455489.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['response'] = df['response'].astype('int')

# %%
df
# Out:
#        customer_id trans_date  tran_amount  response
# 0           CS5295 2013-02-11           35         1
# 1           CS4768 2015-03-15           39         1
# 2           CS2122 2013-02-26           52         0
# 3           CS1217 2011-11-16           99         0
# 4           CS1850 2013-11-20           78         0
# ...            ...        ...          ...       ...
# 124995      CS8433 2011-06-26           64         0
# 124996      CS7232 2014-08-19           38         0
# 124997      CS8731 2014-11-28           42         0
# 124998      CS8133 2013-12-14           13         0
# 124999      CS7996 2014-12-13           36         0
#
# [124969 rows x 4 columns]

# %%
df.dtypes
# Out:
# customer_id            object
# trans_date     datetime64[ns]
# tran_amount             int64
# response                int64
# dtype: object

# %%
df
# Out:
#        customer_id trans_date  tran_amount  response
# 0           CS5295 2013-02-11           35         1
# 1           CS4768 2015-03-15           39         1
# 2           CS2122 2013-02-26           52         0
# 3           CS1217 2011-11-16           99         0
# 4           CS1850 2013-11-20           78         0
# ...            ...        ...          ...       ...
# 124995      CS8433 2011-06-26           64         0
# 124996      CS7232 2014-08-19           38         0
# 124997      CS8731 2014-11-28           42         0
# 124998      CS8133 2013-12-14           13         0
# 124999      CS7996 2014-12-13           36         0
#
# [124969 rows x 4 columns]

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
from scipy import stats

# %%
z_scores = np.abs(stats.zscore(df['tran_amount']))

thresold = 3

outliers = z_scores>thresold

print(sum(outliers))
# Out:
# 0

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
sns.boxplot(x =df ['tran_amount'])
plt.show()

# %%
sns.boxplot(x =df ['response'])
plt.show()

# %%
df['month'] = df['trans_date'].dt.month
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15456\1675453229.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df['trans_date'].dt.month

# %%
df
# Out:
#        customer_id trans_date  tran_amount  response  month
# 0           CS5295 2013-02-11           35         1      2
# 1           CS4768 2015-03-15           39         1      3
# 2           CS2122 2013-02-26           52         0      2
# 3           CS1217 2011-11-16           99         0     11
# 4           CS1850 2013-11-20           78         0     11
# ...            ...        ...          ...       ...    ...
# 124995      CS8433 2011-06-26           64         0      6
# 124996      CS7232 2014-08-19           38         0      8
# 124997      CS8731 2014-11-28           42         0     11
# 124998      CS8133 2013-12-14           13         0     12
# 124999      CS7996 2014-12-13           36         0     12
#
# [124969 rows x 5 columns]

# %%
monthly_sales = df.groupby('month')['tran_amount'].sum()
monthly_sales = monthly_sales.sort_values(ascending = False).reset_index().head(3)

monthly_sales
# Out:
#    month  tran_amount
# 0      8       726775
# 1     10       725058
# 2      1       724089

# %%
customer_count = df['customer_id'].value_counts().reset_index()
customer_count
# Out:
#      customer_id  count
# 0         CS4424     39
# 1         CS4320     38
# 2         CS3799     36
# 3         CS3805     35
# 4         CS1215     35
# ...          ...    ...
# 6879      CS7333      4
# 6880      CS7224      4
# 6881      CS7716      4
# 6882      CS8504      4
# 6883      CS8559      4
#
# [6884 rows x 2 columns]

# %%
top5_cus = customer_count.sort_values(by = 'count', ascending = False).head(5)
top5_cus
# Out:
#   customer_id  count
# 0      CS4424     39
# 1      CS4320     38
# 2      CS3799     36
# 4      CS1215     35
# 3      CS3805     35

# %%
sns.barplot(x= 'customer_id', y = 'count', data = top5_cus, palette = 'Set1')
plt.title('Top 5 Customer')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15456\3264252050.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x= 'customer_id', y = 'count', data = top5_cus, palette = 'Set1')
# Text(0.5, 1.0, 'Top 5 Customer')

# %%
customer_sales = df.groupby('customer_id')['tran_amount'].sum().reset_index()
top5_sales = customer_sales.sort_values(by = 'tran_amount', ascending = False).head(5)
top5_sales
# Out:
#      customer_id  tran_amount
# 3312      CS4424         2933
# 3208      CS4320         2647
# 4640      CS5752         2612
# 3548      CS4660         2527
# 2687      CS3799         2513

# %%
sns.barplot(x = 'customer_id', y = 'tran_amount', data = top5_sales, palette = 'Set1')
plt.title('Top 5 Sales')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15456\1204678044.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'customer_id', y = 'tran_amount', data = top5_sales, palette = 'Set1')
# Text(0.5, 1.0, 'Top 5 Sales')

# %%
import matplotlib.dates as mdate

# %%
df['month_year'] = df['trans_date'].dt.to_period('M')
monthly_sales = df.groupby('month_year')['tran_amount'].sum()

monthly_sales.index = monthly_sales.index.to_timestamp()

plt.figure(figsize = (12,6))
plt.plot(monthly_sales.index, monthly_sales.values)
plt.gca().xaxis.set_major_formatter(mdate.DateFormatter('%Y-%M'))
plt.gca().xaxis.set_major_locator(mdate.MonthLocator(interval = 6))
plt.xlabel('Month-Year')
plt.ylabel('Sales')
plt.title('Monthly Sales')
plt.xticks(rotation = 45)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15456\484835882.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month_year'] = df['trans_date'].dt.to_period('M')
# (array([15095., 15279., 15461., 15645., 15826., 16010., 16191., 16375.,
#         16556.]),
#  [Text(15095.0, 0, '2011-00'),
#   Text(15279.0, 0, '2011-00'),
#   Text(15461.0, 0, '2012-00'),
#   Text(15645.0, 0, '2012-00'),
#   Text(15826.0, 0, '2013-00'),
#   Text(16010.0, 0, '2013-00'),
#   Text(16191.0, 0, '2014-00'),
#   Text(16375.0, 0, '2014-00'),
#   Text(16556.0, 0, '2015-00')])

# %%
recency = df.groupby('customer_id')['trans_date'].max()
frequency = df.groupby('customer_id')['trans_date'].count()
monitary = df.groupby('customer_id')['tran_amount'].sum()

rfm = pd.DataFrame({'recency':recency,'frequency':frequency,'monitary':monitary})

# %%
rfm
# Out:
#                recency  frequency  monitary
# customer_id
# CS1112      2015-01-14         15      1012
# CS1113      2015-02-09         20      1490
# CS1114      2015-02-12         19      1432
# CS1115      2015-03-05         22      1659
# CS1116      2014-08-25         13       857
# ...                ...        ...       ...
# CS8996      2014-12-09         13       582
# CS8997      2014-06-28         14       543
# CS8998      2014-12-22         13       624
# CS8999      2014-07-02         12       383
# CS9000      2015-02-28         13       533
#
# [6884 rows x 3 columns]

# %%
def segment(row):
    if row['recency'].year >= 2012 and row['frequency'] > 15 and row['monitary'] > 1000:
        return 'P0'
    elif (2011 <= row['recency'].year < 2012) and (10 < row['frequency'] < 15) and (500 < row['monitary'] <=1000):
        return 'P1'
    else :
        return 'P2'

rfm ['segment'] = rfm.apply(segment, axis = 1)

# %%
rfm ['segment']
# Out:
# customer_id
# CS1112    P2
# CS1113    P0
# CS1114    P0
# CS1115    P0
# CS1116    P2
#           ..
# CS8996    P2
# CS8997    P2
# CS8998    P2
# CS8999    P2
# CS9000    P2
# Name: segment, Length: 6884, dtype: object

# %%
rfm
# Out:
#                recency  frequency  monitary segment
# customer_id
# CS1112      2015-01-14         15      1012      P2
# CS1113      2015-02-09         20      1490      P0
# CS1114      2015-02-12         19      1432      P0
# CS1115      2015-03-05         22      1659      P0
# CS1116      2014-08-25         13       857      P2
# ...                ...        ...       ...     ...
# CS8996      2014-12-09         13       582      P2
# CS8997      2014-06-28         14       543      P2
# CS8998      2014-12-22         13       624      P2
# CS8999      2014-07-02         12       383      P2
# CS9000      2015-02-28         13       533      P2
#
# [6884 rows x 4 columns]

# %%
df
# Out:
#        customer_id trans_date  tran_amount  response  month month_year  \
# 0           CS5295 2013-02-11           35         1      2    2013-02
# 1           CS4768 2015-03-15           39         1      3    2015-03
# 2           CS2122 2013-02-26           52         0      2    2013-02
# 3           CS1217 2011-11-16           99         0     11    2011-11
# 4           CS1850 2013-11-20           78         0     11    2013-11
# ...            ...        ...          ...       ...    ...        ...
# 124995      CS8433 2011-06-26           64         0      6    2011-06
# 124996      CS7232 2014-08-19           38         0      8    2014-08
# 124997      CS8731 2014-11-28           42         0     11    2014-11
# 124998      CS8133 2013-12-14           13         0     12    2013-12
# 124999      CS7996 2014-12-13           36         0     12    2014-12
#
#         monthly_sales
# 0                 NaN
# 1                 NaN
# 2                 NaN
# ...

# %%
rfm
# Out:
#                recency  frequency  monitary segment
# customer_id
# CS1112      2015-01-14         15      1012      P2
# CS1113      2015-02-09         20      1490      P0
# CS1114      2015-02-12         19      1432      P0
# CS1115      2015-03-05         22      1659      P0
# CS1116      2014-08-25         13       857      P2
# ...                ...        ...       ...     ...
# CS8996      2014-12-09         13       582      P2
# CS8997      2014-06-28         14       543      P2
# CS8998      2014-12-22         13       624      P2
# CS8999      2014-07-02         12       383      P2
# CS9000      2015-02-28         13       533      P2
#
# [6884 rows x 4 columns]

# %%
df.to_csv('MainData.csv')
rfm.to_csv('AddData.csv')
